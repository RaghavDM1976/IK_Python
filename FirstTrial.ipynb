# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghavDM1976/IK_Python/blob/main/FirstTrial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
local_var1 = 100

def method1():
  local_var1 = 10
  print(local_var1)


def example_function():
  print(local_var1)

method1()
example_function()
# Out:
# 10
# 100
